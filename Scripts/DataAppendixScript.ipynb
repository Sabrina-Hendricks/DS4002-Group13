# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabrina-Hendricks/DS4002-Group13/blob/main/Scripts/DataAppendixScript.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/Sabrina-Hendricks/DS4002-Group13/main/Data/Cleaned_Data.csv'
df = pd.read_csv(url)
df.describe()
# Out:
#           Review ID   Clothing ID           Age  Sentiment Score  \
# count  22628.000000  22628.000000  22628.000000     22628.000000
# mean   11737.272097    919.695908     43.282880         0.740518
# std     6781.574232    201.683804     12.328176         0.366806
# min        0.000000      1.000000     18.000000        -0.953200
# 25%     5868.750000    861.000000     34.000000         0.717700
# 50%    11727.500000    936.000000     41.000000         0.891000
# 75%    17617.250000   1078.000000     52.000000         0.950200
# max    23485.000000   1205.000000     99.000000         0.995600
#
#              Rating  Recommended IND  Positive Feedback Count  Review Length
# count  22628.000000     22628.000000             22628.000000   22628.000000
# mean       4.183092         0.818764                 2.631784      60.211950
# std        1.115911         0.385222                 5.787520      28.533053
# ...

# %%
df['Review ID'].describe()
# Out:
# count    22628.000000
# mean     11737.272097
# std       6781.574232
# min          0.000000
# 25%       5868.750000
# 50%      11727.500000
# 75%      17617.250000
# max      23485.000000
# Name: Review ID, dtype: float64

# %%
df['Clothing ID'].describe()
# Out:
# count    22628.000000
# mean       919.695908
# std        201.683804
# min          1.000000
# 25%        861.000000
# 50%        936.000000
# 75%       1078.000000
# max       1205.000000
# Name: Clothing ID, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    22628.000000
# mean        43.282880
# std         12.328176
# min         18.000000
# 25%         34.000000
# 50%         41.000000
# 75%         52.000000
# max         99.000000
# Name: Age, dtype: float64

# %%
df['Sentiment Score'].describe()
# Out:
# count    22628.000000
# mean         0.740518
# std          0.366806
# min         -0.953200
# 25%          0.717700
# 50%          0.891000
# 75%          0.950200
# max          0.995600
# Name: Sentiment Score, dtype: float64

# %%
df['Rating'].describe()
# Out:
# count    22628.000000
# mean         4.183092
# std          1.115911
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: Rating, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Rating'], bins=15, kde=True) #Select age column
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
df['Recommended IND'].describe()
# Out:
# count    22628.000000
# mean         0.818764
# std          0.385222
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: Recommended IND, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Recommended IND'], bins=15, kde=True) #Select age column
plt.title('Distribution of Recommendations')
plt.xlabel('Recommended?')
plt.ylabel('Frequency')
plt.show()

# %%
df['Positive Feedback Count'].describe()
# Out:
# count    22628.000000
# mean         2.631784
# std          5.787520
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          3.000000
# max        122.000000
# Name: Positive Feedback Count, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Positive Feedback Count'], bins=8, kde=True)
plt.title('Distribution of Positive Feedback')
plt.xlabel('Positive Feedback Count')
plt.ylabel('Frequency')
plt.show()

# %%
df['Review Length'].describe()
# Out:
# count    22628.000000
# mean        60.211950
# std         28.533053
# min          2.000000
# 25%         36.000000
# 50%         59.000000
# 75%         88.000000
# max        115.000000
# Name: Review Length, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Review Length'], bins=8, kde=True)
plt.title('Distribution of Review Length')
plt.xlabel('Review Length')
plt.ylabel('Frequency')
plt.show()
